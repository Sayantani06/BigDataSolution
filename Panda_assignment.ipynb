# %%
import pandas as pd

# %%
#Q1. How do you load a CSV file into a Pandas DataFrame?
df=pd.read_csv('https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Q2. How do you check the data type of a column in a Pandas DataFrame?

df.dtypes
#gives the details of every column
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Q2. How do you check the data type of a column in a Pandas DataFrame?

df['Age'].dtypes

# This gives the datatype of the specific column
# Out:
# dtype('float64')

# %%
#Q3. How do you select rows from a Pandas DataFrame based on a condition?

df.loc[1]
#returns the the details of the row1

df_Pclass3=df[df['Pclass']==3]
print(df_Pclass3)
# will return the row which satisfy the column.
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 0              1         0       3                   Braund, Mr. Owen Harris
# 2              3         1       3                    Heikkinen, Miss. Laina
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
#How do you rename columns in a Pandas DataFrame?
df.rename(columns={'Name':'Full Name'},inplace= True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you drop columns in a Pandas DataFrame?
df.drop(['Embarked'],axis=1,inplace=True)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you find the unique values in a column of a Pandas DataFrame?
df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
#How do you find the number of missing values in each column of a Pandas DataFrame?
df.isnull()

#where ever its a null value it will return True.
# Out:
#      PassengerId  Survived  Pclass  Full Name    Sex    Age  SibSp  Parch  \
# 0          False     False   False      False  False  False  False  False
# 1          False     False   False      False  False  False  False  False
# 2          False     False   False      False  False  False  False  False
# 3          False     False   False      False  False  False  False  False
# 4          False     False   False      False  False  False  False  False
# ..           ...       ...     ...        ...    ...    ...    ...    ...
# 886        False     False   False      False  False  False  False  False
# 887        False     False   False      False  False  False  False  False
# 888        False     False   False      False  False   True  False  False
# 889        False     False   False      False  False  False  False  False
# 890        False     False   False      False  False  False  False  False
#
#      Ticket   Fare  Cabin
# 0     False  False   True
# ...

# %%
#Q8. How do you fill missing values in a Pandas DataFrame with a specific value?

df.fillna(0)
#fills the null values with 0
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you concatenate two Pandas DataFrames?

data1={'Name':['Sayan','Raj','Rajat','Vishal'],
     'Age': [22,23,54,25]}
data2={'Name':['John','Raju','Rajoshre','Vish'],
     'Age': [22,23,54,25]}
df1=pd.DataFrame(data1)
df2=pd.DataFrame(data2)

#print(df1)
#print(df2)
#One way of concating
result= pd.concat([df1,df2])
print(result)
#Another way by using concating
res=df1.append(df2)
print(res)
# Out:
#        Name  Age
# 0     Sayan   22
# 1       Raj   23
# 2     Rajat   54
# 3    Vishal   25
# 0      John   22
# 1      Raju   23
# 2  Rajoshre   54
# 3      Vish   25
#        Name  Age
# 0     Sayan   22
# 1       Raj   23
# 2     Rajat   54
# 3    Vishal   25
# 0      John   22
# 1      Raju   23
# 2  Rajoshre   54
# 3      Vish   25

# %%
#How do you merge two Pandas DataFrames on a specific column?

df1 = pd.DataFrame({'Name':['Raju', 'Rani', 'Geeta', 'Sita', 'Sohit'],
                    'Marks':[80, 90, 75, 88, 59]})
df2 = pd.DataFrame({'Name':['Raju', 'Divya', 'Geeta', 'Sita'],
                    'Grade':['A', 'A', 'B', 'A'],
                    'Rank':[3, 1, 4, 2 ],
                    'Gender':['Male', 'Female', 'Female', 'Female']})

  
res=df1.merge(df2[['Name', 'Grade', 'Rank']])
print(res)
# Out:
#     Name  Marks Grade  Rank
# 0   Raju     80     A     3
# 1  Geeta     75     B     4
# 2   Sita     88     A     2

# %%
#How do you group data in a Pandas DataFrame by a specific column and apply an aggregation function?
df
df.groupby('Pclass').agg({'Fare':['mean','min','max']})
# Out:
#              Fare
#              mean  min       max
# Pclass
# 1       84.154687  0.0  512.3292
# 2       20.662183  0.0   73.5000
# 3       13.675550  0.0   69.5500

# %%
#How do you change the data type of a column in a Pandas DataFrame?

df1=df.fillna(0)
df1['Age'].astype(int)
df1.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Full Name       object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# dtype: object

# %%
#How do you sort a Pandas DataFrame by a specific column?

res=df.sort_values(by=['Fare'],ascending=False)
res.head(10)
#ascending= True will give ascending value.ascending=False will give descending value.
# Out:
#      PassengerId  Survived  Pclass                              Full Name  \
# 258          259         1       1                       Ward, Miss. Anna
# 737          738         1       1                 Lesurer, Mr. Gustave J
# 679          680         1       1     Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1             Fortune, Miss. Mabel Helen
# 27            28         0       1         Fortune, Mr. Charles Alexander
# 341          342         1       1         Fortune, Miss. Alice Elizabeth
# 438          439         0       1                      Fortune, Mr. Mark
# 311          312         1       1             Ryerson, Miss. Emily Borie
# 742          743         1       1  Ryerson, Miss. Susan Parker "Suzette"
# 118          119         0       1               Baxter, Mr. Quigg Edmond
#
#         Sex   Age  SibSp  Parch    Ticket      Fare            Cabin
# 258  female  35.0      0      0  PC 17755  512.3292              NaN
# ...

# %%
#How do you create a copy of a Pandas DataFrame?
df4= df1.copy()
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you filter rows of a Pandas DataFrame by multiple conditions?

display(df.loc[(df['Pclass']==3) & (df['Survived']==1)])
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 8              9         1       3
# 10            11         1       3
# 19            20         1       3
# 22            23         1       3
# ..           ...       ...     ...
# 838          839         1       3
# 855          856         1       3
# 858          859         1       3
# 869          870         1       3
# 875          876         1       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 19                             Masselmani, Mrs. Fatima  female   NaN      0
# 22                         McGowan, Miss. Anna "Annie"  female  15.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you calculate the mean of a column in a Pandas DataFrame?
df['Fare'].mean()
# Out:
# 32.204207968574636

# %%
#How do you calculate the standard deviation of a column in a Pandas DataFrame?
df['Fare'].std()
# Out:
# 49.6934285971809

# %%
#How do you select specific columns in a DataFrame using their labels?
df['Fare'] #fetch single coumn
df[['Fare','Pclass']] #multiole
# Out:
#         Fare  Pclass
# 0     7.2500       3
# 1    71.2833       1
# 2     7.9250       3
# 3    53.1000       1
# 4     8.0500       3
# ..       ...     ...
# 886  13.0000       2
# 887  30.0000       1
# 888  23.4500       3
# 889  30.0000       1
# 890   7.7500       3
#
# [891 rows x 2 columns]

# %%
#How do you select specific rows in a DataFrame using their indexes?
df
df.iloc[0:6]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Full Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin
# 0      0         A/5 21171   7.2500   NaN
# 1      0          PC 17599  71.2833   C85
# 2      0  STON/O2. 3101282   7.9250   NaN
# ...

# %%
#How do you sort a DataFrame by a specific column?

df.sort_values(by=['Fare'],ascending=False)
# Out:
#      PassengerId  Survived  Pclass                           Full Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 88            89         1       1          Fortune, Miss. Mabel Helen
# 27            28         0       1      Fortune, Mr. Charles Alexander
# ..           ...       ...     ...                                 ...
# 633          634         0       1       Parr, Mr. William Henry Marsh
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 822          823         0       1     Reuchlin, Jonkheer. John George
# 732          733         0       2                Knight, Mr. Robert J
# 674          675         0       2          Watson, Mr. Ennis Hastings
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin
# ...

# %%
#How do you create a new column in a DataFrame based on the values of another column?
df['newcolumn']=df['PassengerId']+df['Survived']
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                              Full Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#How do you remove duplicates from a DataFrame?
df['Full Name'].drop_duplicates()
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Full Name, Length: 891, dtype: object

# %%
# is the difference between .loc and .iloc in Pandas?

loc is label-based, which means that you have to specify rows and columns based on their row and column labels.
iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).
